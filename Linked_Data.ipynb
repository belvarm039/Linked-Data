# %% [markdown]
# Aisyah Zahrah (5026201023)
#
# Belva Rizki Mufidah (5026201039)

# %%
# !python -m pip install --no-input jupyter-rdfify
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.8/69.8 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 15.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.6 MB/s eta 0:00:00
# ...
#   Created wheel for cfgraph: filename=CFGraph-0.2.1-py3-none-any.whl size=2213 sha256=9c8d3ab5e24559781d51cec582c4adea31d18e499e773105d5f9a91b6c5e0c4c
# ...

# %%
# %reload_ext jupyter-rdfify

# %%
#load CSV dengan pandas
import pandas as pd
#display the table
df = pd.read_csv("/content/sample_data/pizza_hut_locations.csv")
df
# Out:
#       Unnamed: 0               type             address_1 address_2  \
# 0              0  Pizza Hut Express  1200 N. Muldoon Road       NaN
# 1              1  Pizza Hut Express    150 West 100th Ave   Suite A
# 2              2          Pizza Hut        2220 Abbott Rd       NaN
# 3              3          Pizza Hut     341 Boniface Pkwy    Unit G
# 4              4          Pizza Hut  3727 Spenard Highway       NaN
# ...          ...                ...                   ...       ...
# 6595        6595          Pizza Hut        2547 N Main St       NaN
# 6596        6596          Pizza Hut       545 Shoshoni St       NaN
# 6597        6597          Pizza Hut        1120 E. Valley       NaN
# 6598        6598          Pizza Hut        1801 N 16th St       NaN
# 6599        6599          Pizza Hut   1935 E Big Horn Ave       NaN
#
#                open_hours         city state  postal_code  latitude  longitude
# ...

# %%
# %%rdf turtle
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>.
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix ex: <http://example.org/#>.
# @prefix gr: <http://purl.org/goodrelations/v1>.
# @prefix s: <http://schema.org/>.
# @prefix wikidata: <http://www.wikidata.org/>.
# @prefix wikipedia: <https://en.wikipedia.org/wiki/>.
# @prefix gn: <https://www.geonames.org/>.
# @prefix dbpedia: <https://dbpedia.org/resource/> .
#
# ex:restaurant1 a gr:Location;
#     gr:category dbpedia:Pizza_Hut_Express;
#     gr:hasOpeningHoursSpecification
#          [ a gr:OpeningHoursSpecification;
#            gr:opens "10:00:00"^^xsd:time;
#            gr:closes "23:00:00"^^xsd:time ];
#     s:address [ a s:PostalAddress;
#                 s:streetAddress "1200 N. Muldoon Road";
#                 s:postalCode "99504";
#                 rdfs:seeAlso gn:Anchorage ].
#
# ex:restaurant2 a gr:Location;
#     gr:category dbpedia:Pizza_Hut_Express;
#     gr:hasOpeningHoursSpecification
#          [ a gr:OpeningHoursSpecification;
#            gr:opens "10:00:00"^^xsd:tim
#            gr:closes "23:00:00"^^xsd:time ];
#     s:address [ a s:PostalAddress;
#                 s:streetAddress "150 West 100th Ave";
#                 s:postalCode "99515";
#                 rdfs:seeAlso gn:Anchorage ].
#
# ex:restaurant3 a gr:Location;
#     gr:category dbpedia:pizza-hut ;
#     gr:hasOpeningHoursSpecification
#          [ a gr:OpeningHoursSpecification;
#            gr:opens "10:00:00"^^xsd:time;
#            gr:closes "23:00:00"^^xsd:time ];
#     s:address [ a s:PostalAddress;
#                 s:streetAddress "2220 Abbott Rd";
#                 s:postalCode "99507";
#                 rdfs:seeAlso gn:Anchorage ].

# %% [markdown]
# Belva Rizki, Aisyah Zahrah, and Nur Aini Rakhmawati. "Vocabulary Extended Pizza Hut Restaurants Locations in US" https://www.researchgate.net/publication/374005739_Vocabulary_Extended_Pizza_Hut_Restaurants_Locations_in_US?_tp=eyJjb250ZXh0Ijp7ImZpcnN0UGFnZSI6Il9kaXJlY3QiLCJwYWdlIjoicHJvZmlsZSIsInByZXZpb3VzUGFnZSI6InB1YmxpY2F0aW9uIiwicG9zaXRpb24iOiJwYWdlQ29udGVudCJ9fQ
